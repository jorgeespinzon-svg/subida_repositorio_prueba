# %% [markdown]
# # ¡Hola Jorge! <a class="tocSkip"></a>
#
# Mi nombre es Oscar Flores y tengo el gusto de revisar tu proyecto. Si tienes algún comentario que quieras agregar en tus respuestas te puedes referir a mi como Oscar, no hay problema que me trates de tú.
#
# Si veo un error en la primera revisión solamente lo señalaré y dejaré que tú encuentres de qué se trata y cómo arreglarlo. Debo prepararte para que te desempeñes como especialista en Data, en un trabajo real, el responsable a cargo tuyo hará lo mismo. Si aún tienes dificultades para resolver esta tarea, te daré indicaciones más precisas en una siguiente iteración.
#
# Te dejaré mis comentarios más abajo - **por favor, no los muevas, modifiques o borres**
#
# Comenzaré mis comentarios con un resumen de los puntos que están bien, aquellos que debes corregir y aquellos que puedes mejorar. Luego deberás revisar todo el notebook para leer mis comentarios, los cuales estarán en rectángulos de color verde, amarillo o rojo como siguen:
#
# <div class='alert alert-block alert-success'>
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Muy bien! Toda la respuesta fue lograda satisfactoriamente.
# </div>
#
# <div class='alert alert-block alert-warning'>
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Existen detalles a mejorar. Existen recomendaciones.
# </div>
#
# <div class='alert alert-block alert-danger'>
#
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Se necesitan correcciones en el bloque. El trabajo no puede ser aceptado con comentarios en rojo sin solucionar.
# </div>
#
# Cualquier comentario que quieras agregar entre iteraciones de revisión lo puedes hacer de la siguiente manera:
#
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante.</b> <a class='tocSkip'></a>
# </div>
#
# Mucho éxito en el proyecto!

# %% [markdown]
# ## Resumen de la revisión v2 <a class="tocSkip"></a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor  v2 </b> <a class="tocSkip"></a>
#
# ¡Buen trabajo Jorge! Las últimas correcciones quedaron muy bien. Completaste todas las tareas del notebook de forma correcta, así que no tengo más observaciones que hacer. El proyecto está aprobado. Todo lo que aplicaste aquí será de gran valor en futuros análisis. ¡Mucho éxito en lo que viene!
#
# Saludos.
#
# </div>

# %% [markdown]
# ----

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# 👋 **¡Hola! Soy Dot, tu revisor de IA.**
#
# He completado la primera revisión de tu código. A continuación, encontrarás mis comentarios y sugerencias de mejora.
#
# **¿Qué debes hacer ahora?**
#
# 1. **Revisar:** Lee mis comentarios en el notebook más abajo.
# 2. **Decidir:**
# * **¿Estás de acuerdo con el feedback?** ¡Genial! Actualiza tu código según las sugerencias.
# * **¿No estás de acuerdo o crees que es un error?** ¡No hay problema! Puedes dejar tu código exactamente como está.
#
#
# 3. **Volver a enviar:** Envía tu proyecto de nuevo. **Tu próxima iteración será revisada por un experto humano**, independientemente de si hiciste cambios o no.
#
# -------------------------------------------------------------------------------------------------------------
# Mis comentarios están más abajo. **Te pido amablemente que no los muevas, modifiques ni elimines**.
#
# Verás mis comentarios resaltados en cuadros verdes, amarillos o rojos como estos:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Correcto. Todo se ha hecho exitosamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Necesita corrección. El bloque requiere algunas correcciones.
# </div>

# %% [markdown]
# # ¿Cuál es la mejor tarifa?
#
# Trabajas como analista para el operador de telecomunicaciones Megaline. La empresa ofrece a sus clientes dos tarifas de prepago, Surf y Ultimate. El departamento comercial quiere saber cuál de las tarifas genera más ingresos para poder ajustar el presupuesto de publicidad.
#
# Vas a realizar un análisis preliminar de las tarifas basado en una selección de clientes relativamente pequeña. Tendrás los datos de 500 clientes de Megaline: quiénes son los clientes, de dónde son, qué tarifa usan, así como la cantidad de llamadas que hicieron y los mensajes de texto que enviaron en 2018. Tu trabajo es analizar el comportamiento de los clientes y determinar qué tarifa de prepago genera más ingresos.

# %% [markdown]
# [Te proporcionamos algunos comentarios para orientarte mientras completas este proyecto. Pero debes asegurarte de eliminar todos los comentarios entre corchetes antes de entregar tu proyecto.]
#
# [Antes de sumergirte en el análisis de datos, explica por tu propia cuenta el propósito del proyecto y las acciones que planeas realizar.]
#
# [Ten en cuenta que estudiar, modificar y analizar datos es un proceso iterativo. Es normal volver a los pasos anteriores y corregirlos/ampliarlos para permitir nuevos pasos.]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La introducción todavía contiene las indicaciones de plantilla entre corchetes. Considera eliminar esas líneas entre corchetes y reemplazarlas con tu propio breve resumen del proyecto (objetivo, pasos principales y lo que planeas concluir).
#
# </div>

# %% [markdown]
# ## Inicialización

# %%
# Cargar todas las librerías
import pandas as pd
from scipy import stats as st
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Aqui traje todas las librerias con las que he trabajado

# %% [markdown]
# ## Cargar datos

# %%
# Carga los archivos de datos en diferentes DataFrames
users = pd.read_csv('/datasets/megaline_users.csv')
calls = pd.read_csv('/datasets/megaline_calls.csv')
messages = pd.read_csv('/datasets/megaline_messages.csv')
internet = pd.read_csv('/datasets/megaline_internet.csv')
plans = pd.read_csv('/datasets/megaline_plans.csv')

# %% [markdown]
# Aqui traje los data frames mediantes pandas

# %% [markdown]
# ## Preparar los datos

# %% [markdown]
# [Los datos para este proyecto se dividen en varias tablas. Explora cada una para tener una comprensión inicial de los datos. Si es necesario, haz las correcciones requeridas en cada tabla.]

# %%
# Imprime la información general/resumida sobre el DataFrame de las tarifas

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Todavía falta este paso de exploración para la tabla **plans**. Considera imprimir aquí el resumen del DataFrame **plans** (columnas, dtypes, valores faltantes) para que puedas confirmar explícitamente el esquema antes de cualquier preprocesamiento y de los cálculos de facturación.
#
# </div>

# %%
#1 Visualización de los datos
users
# Out:
#      user_id first_name   last_name  age  \
# 0       1000   Anamaria       Bauer   45
# 1       1001     Mickey   Wilkerson   28
# 2       1002     Carlee     Hoffman   36
# 3       1003   Reynaldo     Jenkins   52
# 4       1004    Leonila    Thompson   40
# ..       ...        ...         ...  ...
# 495     1495      Fidel      Sharpe   67
# 496     1496      Ariel    Shepherd   49
# 497     1497      Donte     Barrera   49
# 498     1498       Scot  Williamson   51
# 499     1499      Shena     Dickson   37
#
#                                           city    reg_date      plan  \
# 0        Atlanta-Sandy Springs-Roswell, GA MSA  2018-12-24  ultimate
# 1              Seattle-Tacoma-Bellevue, WA MSA  2018-08-13      surf
# 2         Las Vegas-Henderson-Paradise, NV MSA  2018-10-21      surf
# 3                                Tulsa, OK MSA  2018-01-28      surf
# 4              Seattle-Tacoma-Bellevue, WA MSA  2018-05-23      surf
# ...

# %%
#2 Visualización del formato de cada columna
users.info()
print("# de filas duplicadas",users.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   first_name  500 non-null    object
#  2   last_name   500 non-null    object
#  3   age         500 non-null    int64
#  4   city        500 non-null    object
#  5   reg_date    500 non-null    object
#  6   plan        500 non-null    object
#  7   churn_date  34 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
# # de filas duplicadas 0

# %%
#3 Correccion a groso modo de los datos de la tabla Users y visualizacion de modificaciones
users['reg_date'] = pd.to_datetime(users['reg_date'])
users['churn_date'] = pd.to_datetime(users['churn_date'])
# Se clarifica que la columna chrun_date es usada para saber cuando los clientes dejaron de usar el servicio así:
# fecha = fecha de salida del servicio y NaN = sigue con el servicio activo
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   first_name  500 non-null    object
#  2   last_name   500 non-null    object
#  3   age         500 non-null    int64
#  4   city        500 non-null    object
#  5   reg_date    500 non-null    datetime64[ns]
#  6   plan        500 non-null    object
#  7   churn_date  34 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 31.4+ KB

# %%
#1 Visualización de los datos
calls
# Out:
#               id  user_id   call_date  duration
# 0        1000_93     1000  2018-12-27      8.52
# 1       1000_145     1000  2018-12-27     13.66
# 2       1000_247     1000  2018-12-27     14.48
# 3       1000_309     1000  2018-12-28      5.76
# 4       1000_380     1000  2018-12-30      4.22
# ...          ...      ...         ...       ...
# 137730  1499_199     1499  2018-11-21      8.72
# 137731  1499_200     1499  2018-10-20     10.89
# 137732  1499_201     1499  2018-09-21      8.12
# 137733  1499_202     1499  2018-10-10      0.37
# 137734  1499_203     1499  2018-12-29     13.86
#
# [137735 rows x 4 columns]

# %%
#2 Visualización del formato de cada columna y Duplicados
calls.info()
print("# de filas duplicadas",calls.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  object
#  3   duration   137735 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB
# # de filas duplicadas 0

# %%
#3 Correccion a groso modo de los datos de la tabla calls y visualizacion de modificaciones
calls["call_date"] = pd.to_datetime(calls["call_date"])
calls.info()
#No se observa ningun NaN
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  datetime64[ns]
#  3   duration   137735 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 4.2+ MB

# %%
#1 Visualización de los datos
messages
# Out:
#              id  user_id message_date
# 0      1000_125     1000   2018-12-27
# 1      1000_160     1000   2018-12-31
# 2      1000_223     1000   2018-12-31
# 3      1000_251     1000   2018-12-27
# 4      1000_255     1000   2018-12-26
# ...         ...      ...          ...
# 76046  1497_526     1497   2018-12-24
# 76047  1497_536     1497   2018-12-24
# 76048  1497_547     1497   2018-12-31
# 76049  1497_558     1497   2018-12-24
# 76050  1497_613     1497   2018-12-23
#
# [76051 rows x 3 columns]

# %%
#2 Visualización del formato de cada columna y Duplicados
messages.info()
print("# de filas duplicadas",messages.duplicated().sum())
# No hay NaN ni filas duplicadas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB
# # de filas duplicadas 0

# %%
#3 Correccion a groso modo de los datos de la tabla calls y visualizacion de modificaciones
messages["message_date"] = pd.to_datetime(messages["message_date"])
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
#1 Visualización de los datos
internet
# Out:
#               id  user_id session_date  mb_used
# 0        1000_13     1000   2018-12-29    89.86
# 1       1000_204     1000   2018-12-31     0.00
# 2       1000_379     1000   2018-12-28   660.40
# 3       1000_413     1000   2018-12-26   270.99
# 4       1000_442     1000   2018-12-27   880.22
# ...          ...      ...          ...      ...
# 104820  1499_215     1499   2018-10-20   218.06
# 104821  1499_216     1499   2018-12-30   304.72
# 104822  1499_217     1499   2018-09-22   292.75
# 104823  1499_218     1499   2018-12-07     0.00
# 104824  1499_219     1499   2018-12-24   758.31
#
# [104825 rows x 4 columns]

# %%
#2 Visualización del formato de cada columna y Duplicados
internet.info()
print("# de filas duplicadas",internet.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  object
#  3   mb_used       104825 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ MB
# # de filas duplicadas 0

# %%
#3 Correccion a groso modo de los datos de la tabla calls y visualizacion de modificaciones
internet["session_date"] = pd.to_datetime(internet["session_date"])
internet.info()
#No hay Nan ni duplicados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  datetime64[ns]
#  3   mb_used       104825 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 3.2+ MB

# %%
#Cambio de nombre de la columna
plans = plans.rename(columns={'usd_monthly_pay': 'usd_monthly_fee'})
print(plans.head())
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_fee  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %%
#1 Visualización de los datos
plans
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_fee  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Por favor, vuelve a revisar el esquema de **plans**: el diccionario del proyecto suele usar un campo de cuota mensual como `usd_monthly_fee`, pero tu tabla tiene `usd_monthly_pay`. Si esto es un cambio de nombre, documéntalo brevemente; si no, confirma que cargaste el dataset esperado y que todos los cálculos de ingresos posteriores hagan referencia a la columna correcta de cuota mensual.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor      v2    </b> <a class="tocSkip"></a>
#
#
# Muy bien, corregido este punto
#
#
# </div>

# %%
#2 Visualización del formato de cada columna y Duplicados
plans.info()
print("# de filas duplicadas",plans.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   usd_monthly_fee        2 non-null      int64
#  4   usd_per_gb             2 non-null      int64
#  5   usd_per_message        2 non-null      float64
#  6   usd_per_minute         2 non-null      float64
#  7   plan_name              2 non-null      object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 256.0+ bytes
# # de filas duplicadas 0

# %%
#3 Correccion a groso modo de los datos de la tabla calls y visualizacion de modificaciones
# Convertir de USD por GB a USD por MB

plans["usd_per_gb"] = plans["usd_per_gb"] / 1024

# Renombrar la columna usando el diccionario
plans = plans.rename(columns={"usd_per_gb": "usd_per_mb"})

# Verificar los cambios
print(plans.head(2))
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_fee  usd_per_mb  usd_per_message  usd_per_minute plan_name
# 0               20    0.009766             0.03            0.03      surf
# 1               70    0.006836             0.01            0.01  ultimate

# %%
# PASO 1: Crear las columnas de mes primero
calls['month'] = calls['call_date'].dt.month
internet['month'] = internet['session_date'].dt.month
messages['month'] = messages['message_date'].dt.month

# PASO 2: Redondear duración de llamadas
calls['duration_rounded'] = np.ceil(calls['duration'])

# PASO 3: Agregaciones
cantidad_minutos_xusuario = calls.groupby(['user_id','month'])['duration_rounded'].sum().reset_index()

# PASO 4: Para internet - AGREGAR PRIMERO, LUEGO CONVERTIR Y REDONDEAR
trafico_internet_xusuariomes = internet.groupby(['user_id','month'])['mb_used'].sum().reset_index()
# Convertir a GB y redondear hacia arriba DESPUÉS de la agregación
trafico_internet_xusuariomes['gb_used'] = np.ceil(trafico_internet_xusuariomes['mb_used'] / 1024)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Convertir el precio de excedente de “por GB” a “por MB” cambia la lógica de facturación con respecto a los requisitos del proyecto. La tarea normalmente cobra los datos adicionales en GB completos (después de redondear hacia arriba el uso mensual), así que considera mantener la tabla de tarifas en las unidades originales (por GB) y aplicar la regla de redondeo a GB en la etapa de uso mensual, en lugar de cambiar las unidades de la tarifa.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor   v2       </b> <a class="tocSkip"></a>
#
#
# Ok, bien hecho con la conversión después de la agrupación mensual.
#
#
# </div>

# %% [markdown]
# Lo que realice aqui fue una conversion para dejar todas las unidades de forma correcta, para los diferentes calculos mas adelante

# %% [markdown]
# ## Tarifas

# %%
# Imprime una muestra de los datos para las tarifas
print("Datos de las tarifas:")
print(plans)
print('='*100)
print("\nInformación general:")
plans.info()
# Out:
# Datos de las tarifas:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_fee  usd_per_mb  usd_per_message  usd_per_minute plan_name
# 0               20    0.009766             0.03            0.03      surf
# 1               70    0.006836             0.01            0.01  ultimate
# ...
#
# Información general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   usd_monthly_fee        2 non-null      int64
#  4   usd_per_mb             2 non-null      float64
#  5   usd_per_message        2 non-null      float64
# ...

# %% [markdown]
# Considere importante generar un analisis de los datos y limpieza ya que se pueden observar datos vacios, datos con diferencia de formato en las fechas.

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta narrativa obligatoria sigue siendo el marcador de posición de la plantilla. Considera reemplazarla con tus propias observaciones breves sobre la tabla de planes (dtypes, cualquier valor faltante, si las unidades coinciden con la descripción del proyecto y qué—si es que algo—cambiaste y por qué).
#
# </div>

# %% [markdown]
# ## Corregir datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %% [markdown]
# Creo que ya corregui lo observado en el punto 1.3, asi que traere las tablas nuevamente:

# %%
users
# Out:
#      user_id first_name   last_name  age  \
# 0       1000   Anamaria       Bauer   45
# 1       1001     Mickey   Wilkerson   28
# 2       1002     Carlee     Hoffman   36
# 3       1003   Reynaldo     Jenkins   52
# 4       1004    Leonila    Thompson   40
# ..       ...        ...         ...  ...
# 495     1495      Fidel      Sharpe   67
# 496     1496      Ariel    Shepherd   49
# 497     1497      Donte     Barrera   49
# 498     1498       Scot  Williamson   51
# 499     1499      Shena     Dickson   37
#
#                                           city   reg_date      plan churn_date
# 0        Atlanta-Sandy Springs-Roswell, GA MSA 2018-12-24  ultimate        NaT
# 1              Seattle-Tacoma-Bellevue, WA MSA 2018-08-13      surf        NaT
# 2         Las Vegas-Henderson-Paradise, NV MSA 2018-10-21      surf        NaT
# 3                                Tulsa, OK MSA 2018-01-28      surf        NaT
# ...

# %%
calls
# Out:
#               id  user_id  call_date  duration  month  duration_rounded
# 0        1000_93     1000 2018-12-27      8.52     12               9.0
# 1       1000_145     1000 2018-12-27     13.66     12              14.0
# 2       1000_247     1000 2018-12-27     14.48     12              15.0
# 3       1000_309     1000 2018-12-28      5.76     12               6.0
# 4       1000_380     1000 2018-12-30      4.22     12               5.0
# ...          ...      ...        ...       ...    ...               ...
# 137730  1499_199     1499 2018-11-21      8.72     11               9.0
# 137731  1499_200     1499 2018-10-20     10.89     10              11.0
# 137732  1499_201     1499 2018-09-21      8.12      9               9.0
# 137733  1499_202     1499 2018-10-10      0.37     10               1.0
# 137734  1499_203     1499 2018-12-29     13.86     12              14.0
#
# [137735 rows x 6 columns]

# %%
messages
# Out:
#              id  user_id message_date  month
# 0      1000_125     1000   2018-12-27     12
# 1      1000_160     1000   2018-12-31     12
# 2      1000_223     1000   2018-12-31     12
# 3      1000_251     1000   2018-12-27     12
# 4      1000_255     1000   2018-12-26     12
# ...         ...      ...          ...    ...
# 76046  1497_526     1497   2018-12-24     12
# 76047  1497_536     1497   2018-12-24     12
# 76048  1497_547     1497   2018-12-31     12
# 76049  1497_558     1497   2018-12-24     12
# 76050  1497_613     1497   2018-12-23     12
#
# [76051 rows x 4 columns]

# %%
internet
# Out:
#               id  user_id session_date  mb_used  month
# 0        1000_13     1000   2018-12-29    89.86     12
# 1       1000_204     1000   2018-12-31     0.00     12
# 2       1000_379     1000   2018-12-28   660.40     12
# 3       1000_413     1000   2018-12-26   270.99     12
# 4       1000_442     1000   2018-12-27   880.22     12
# ...          ...      ...          ...      ...    ...
# 104820  1499_215     1499   2018-10-20   218.06     10
# 104821  1499_216     1499   2018-12-30   304.72     12
# 104822  1499_217     1499   2018-09-22   292.75      9
# 104823  1499_218     1499   2018-12-07     0.00     12
# 104824  1499_219     1499   2018-12-24   758.31     12
#
# [104825 rows x 5 columns]

# %%
plans
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_fee  usd_per_mb  usd_per_message  usd_per_minute plan_name
# 0               20    0.009766             0.03            0.03      surf
# 1               70    0.006836             0.01            0.01  ultimate

# %% [markdown]
# ## Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %%
# Entiendo segun la ayuda de la app que deberia generar ciertas adiciones como esto:
# 1 Separar en nuevas columnas por mes y año (Necesito que me expliquen porque no veo la necesidad)
calls['month'] = calls['call_date'].dt.month
calls['year'] = calls['call_date'].dt.year

messages['month'] = messages['message_date'].dt.month
messages['year'] = messages['message_date'].dt.year


internet['month'] = internet['session_date'].dt.month
internet['year'] = internet['session_date'].dt.year


# Calcular cuántos meses lleva cada usuario con el servicio(Explicar)
users['subscription_months'] = 12 - users['reg_date'].dt.month + 1


# Clasificar usuarios por edad
users['age_group'] = pd.cut(users['age'], 
                           bins=[0, 30, 50, 100], 
                           labels=['Joven', 'Adulto', 'Mayor'])
##################################################################################

users['month'] = users['reg_date'].dt.month
users['year'] = users['reg_date'].dt.year

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# En este paso de “enrich data”, sería útil justificar claramente las columnas adicionales que creas y cómo se utilizarán más adelante en la agregación mensual/ingresos (por ejemplo, por qué se necesitan mes/año). Si decides no añadir factores derivados del plan, considera indicarlo explícitamente; de lo contrario, muestra cualquier campo derivado relacionado con el plan en unidades consistentes que se alineen con las reglas de facturación.
#
# </div>

# %% [markdown]
# ## Usuarios/as

# %%
# Imprime la información general/resumida sobre el DataFrame de usuarios
print(users.head(3))
users.info()
# Out:
#    user_id first_name  last_name  age                                   city  \
# 0     1000   Anamaria      Bauer   45  Atlanta-Sandy Springs-Roswell, GA MSA
# 1     1001     Mickey  Wilkerson   28        Seattle-Tacoma-Bellevue, WA MSA
# 2     1002     Carlee    Hoffman   36   Las Vegas-Henderson-Paradise, NV MSA
#
#     reg_date      plan churn_date  subscription_months age_group  month  year
# 0 2018-12-24  ultimate        NaT                    1    Adulto     12  2018
# 1 2018-08-13      surf        NaT                    5     Joven      8  2018
# 2 2018-10-21      surf        NaT                    3    Adulto     10  2018
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              500 non-null    int64
#  1   first_name           500 non-null    object
# ...

# %%
# Imprime una muestra de datos para usuarios
print(users.sample(10))
# Out:
#      user_id first_name  last_name  age  \
# 477     1477     Magaly      Rivas   52
# 366     1366        Rod       Huff   62
# 187     1187     Tanner    Goodman   49
# 155     1155     Claude       Hahn   19
# 14      1014    Edmundo      Simon   61
# 352     1352      Gavin   Galloway   48
# 31      1031       Lane     Martin   52
# 91      1091     Taylor     Oliver   38
# 260     1260       Alia    Aguilar   36
# 408     1408     Alaine  Robertson   40
#
#                                               city   reg_date      plan  \
# 477       Riverside-San Bernardino-Ontario, CA MSA 2018-08-24  ultimate
# 366                       Cincinnati, OH-KY-IN MSA 2018-07-30      surf
# 187           Austin-Round Rock-Georgetown, TX MSA 2018-02-20      surf
# 155  Miami-Fort Lauderdale-West Palm Beach, FL MSA 2018-02-21  ultimate
# 14       New York-Newark-Jersey City, NY-NJ-PA MSA 2018-11-25      surf
# 352                Seattle-Tacoma-Bellevue, WA MSA 2018-09-08  ultimate
# ...

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta sección sigue siendo el prompt de plantilla entre corchetes. Considera reemplazarlo con tus propias observaciones sobre la tabla Users (en particular, los valores faltantes en `churn_date`, los tipos de datos de fecha y cualquier verificación que hayas realizado para detectar duplicados/valores atípicos) y lo que hiciste (o no necesitaste) corregir.
#
# </div>

# %% [markdown]
# ### Corregir los datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %% [markdown]
# Ya se realizo en el punto 1.3

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Decir que las correcciones se hicieron en otro lugar no documenta el paso requerido de “fix data” para la tabla Users. Considera resumir brevemente qué corregiste (p. ej., conversiones de fechas, duplicados, valores faltantes) y referenciar el paso/celda exacto anterior donde se hizo, para que el notebook se lea como una narrativa completa.
#
# </div>

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %% [markdown]
# Ya lo realice tambien

# %% [markdown]
# ## Llamadas

# %%
# Imprime la información general/resumida sobre el DataFrame de las llamadas
print(calls.head(3))
calls.info()
# Out:
#          id  user_id  call_date  duration  month  duration_rounded  year
# 0   1000_93     1000 2018-12-27      8.52     12               9.0  2018
# 1  1000_145     1000 2018-12-27     13.66     12              14.0  2018
# 2  1000_247     1000 2018-12-27     14.48     12              15.0  2018
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                137735 non-null  object
#  1   user_id           137735 non-null  int64
#  2   call_date         137735 non-null  datetime64[ns]
#  3   duration          137735 non-null  float64
#  4   month             137735 non-null  int64
#  5   duration_rounded  137735 non-null  float64
#  6   year              137735 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(1)
# memory usage: 7.4+ MB

# %%
# Imprime una muestra de datos para las llamadas
print(calls.sample(10))
# Out:
#              id  user_id  call_date  duration  month  duration_rounded  year
# 88153  1324_199     1324 2018-04-15      0.00      4               0.0  2018
# 74841  1264_103     1264 2018-10-15      3.27     10               4.0  2018
# 14305  1059_536     1059 2018-05-23      5.37      5               6.0  2018
# 58522  1211_131     1211 2018-10-14     16.22     10              17.0  2018
# 41371  1152_421     1152 2018-11-12      0.00     11               0.0  2018
# 49974  1181_236     1181 2018-11-16      5.89     11               6.0  2018
# 22405  1082_416     1082 2018-08-13     13.08      8              14.0  2018
# 40523  1149_211     1149 2018-12-26      0.04     12               1.0  2018
# 60700   1220_48     1220 2018-06-13     16.97      6              17.0  2018
# 68450  1246_469     1246 2018-03-29      4.51      3               5.0  2018

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta sección sigue siendo el prompt de marcador de posición. Considera agregar una breve interpretación escrita de lo que observas en los datos de Calls (dtypes, presencia de llamadas con duración 0, cualquier anomalía) y qué planeas hacer al respecto en el paso de limpieza.
#
# </div>

# %% [markdown]
# ### Corregir los datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %%
# PASO CONVERTIR Y REDONDEAR
calls['duration_rounded'] = np.ceil(calls['duration'])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Regla de facturación importante: la duración de **cada llamada individual** debe redondearse hacia arriba al siguiente minuto completo **antes** de agregar (aggregate) los minutos mensuales por usuario. Sin esto, los minutos mensuales y todos los cálculos de ingresos se subestimarán.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor   v2       </b> <a class="tocSkip"></a>
#
# Muy bien, correcto!
#
#
#
# </div>

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %% [markdown]
# no siento que necesite mas datos

# %% [markdown]
# ## Mensajes

# %%
# Imprime la información general/resumida sobre el DataFrame de los mensajes
print(messages.head(3))
messages.info()
# Out:
#          id  user_id message_date  month  year
# 0  1000_125     1000   2018-12-27     12  2018
# 1  1000_160     1000   2018-12-31     12  2018
# 2  1000_223     1000   2018-12-31     12  2018
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  datetime64[ns]
#  3   month         76051 non-null  int64
#  4   year          76051 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 2.9+ MB

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# En la exploración de mensajes, la salida de “sample” proviene de `calls.sample(10)` en lugar de `messages.sample(10)`. Considera volver a imprimir una muestra real de la tabla de mensajes para que tu exploración coincida con el conjunto de datos que se está analizando.
#
# </div>

# %%
# Imprime una muestra de datos para los mensajes
print(calls.sample(10))
# Out:
#                id  user_id  call_date  duration  month  duration_rounded  year
# 108179  1382_1329     1382 2018-08-21      9.37      8              10.0  2018
# 62790    1226_189     1226 2018-10-15      7.28     10               8.0  2018
# 89663    1326_314     1326 2018-08-15      0.00      8               0.0  2018
# 57949    1209_449     1209 2018-10-30      5.14     10               6.0  2018
# 72786    1257_526     1257 2018-09-27      9.24      9              10.0  2018
# 54182     1196_59     1196 2018-09-24     17.70      9              18.0  2018
# 112099    1394_24     1394 2018-11-07      0.37     11               1.0  2018
# 126737   1451_137     1451 2018-10-23      0.00     10               0.0  2018
# 121537   1427_205     1427 2018-08-14      0.00      8               0.0  2018
# 27045    1101_372     1101 2018-11-03      2.79     11               3.0  2018

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La descripción escrita requerida para la tabla de mensajes aún se mantiene como el marcador de posición de la plantilla. Considera agregar una breve explicación sobre los tipos de datos, los valores faltantes y cualquier verificación/corrección específica de los mensajes que hayas realizado (o confirmar que no fue necesario hacer ninguna).
#
# </div>

# %% [markdown]
# ### Corregir los datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %% [markdown]
# ## Internet

# %%
# Imprime la información general/resumida sobre el DataFrame de internet
print(internet.head(3))
internet.info()
# Out:
#          id  user_id session_date  mb_used  month  year
# 0   1000_13     1000   2018-12-29    89.86     12  2018
# 1  1000_204     1000   2018-12-31     0.00     12  2018
# 2  1000_379     1000   2018-12-28   660.40     12  2018
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  datetime64[ns]
#  3   mb_used       104825 non-null  float64
#  4   month         104825 non-null  int64
#  5   year          104825 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 4.8+ MB

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Para la tabla de Internet, faltan las observaciones escritas requeridas. Considera añadir una verificación breve basada en datos (valores faltantes, sesiones de 0 MB, outliers) e indicar qué decidiste hacer con ellos (conservar, filtrar o justificar por qué no se requieren cambios).
#
# </div>

# %%
# Imprime una muestra de datos para el tráfico de internet
print(internet.sample(10))
# Out:
#              id  user_id session_date  mb_used  month  year
# 81498   1382_28     1382   2018-07-15   353.66      7  2018
# 47386   1212_19     1212   2018-10-25   908.06     10  2018
# 76425  1359_106     1359   2018-09-06   625.92      9  2018
# 35360   1160_64     1160   2018-12-02   726.16     12  2018
# 20898  1097_136     1097   2018-10-23   324.13     10  2018
# 8681   1045_380     1045   2018-12-06   262.38     12  2018
# 31271  1142_322     1142   2018-11-03   486.89     11  2018
# 97905   1461_29     1461   2018-12-15   599.64     12  2018
# 74388  1349_148     1349   2018-10-17   693.19     10  2018
# 34835  1156_432     1156   2018-08-30     0.00      8  2018

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]

# %% [markdown]
# ### Corregir los datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Regla clave de facturación para datos: el uso mensual de internet debe convertirse a GB y redondearse hacia arriba a gigabytes enteros *después* de sumar el uso por usuario por mes. Este paso de redondeo aún no está implementado, y afectará los cargos por exceso (overage) y los ingresos.
#
# </div>

# %%
trafico_internet_xusuariomes = internet.groupby(['user_id','month'])['mb_used'].sum().reset_index()
trafico_internet_xusuariomes['gb_used'] = np.ceil(trafico_internet_xusuariomes['mb_used'] / 1024)

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %% [markdown]
# ## Estudiar las condiciones de las tarifas

# %% [markdown]
# [Es sumamente importante entender cómo funcionan las tarifas, cómo se les cobra a los usuarios en función de su plan de suscripción. Así que te sugerimos imprimir la información de la tarifa para ver una vez más sus condiciones.]

# %%
# Imprime las condiciones de la tarifa y asegúrate de que te quedan claras
plans
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_fee  usd_per_mb  usd_per_message  usd_per_minute plan_name
# 0               20    0.009766             0.03            0.03      surf
# 1               70    0.006836             0.01            0.01  ultimate

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen paso al imprimir las condiciones del plan en una tabla compacta—esto facilita mucho validar los límites incluidos y los precios por excedente antes de implementar el cálculo de ingresos.
#
# </div>

# %% [markdown]
# ## Agregar datos por usuario
#
# [Ahora que los datos están limpios, agrega los datos por usuario y por periodo para que solo haya un registro por usuario y por periodo. Esto facilitará mucho el análisis posterior.]

# %%
# Calcula el número de llamadas hechas por cada usuario al mes. Guarda el resultado.
# Contar llamadas por usuario y mes
calls_per_user_month = calls.groupby(['user_id', 'month']).size().reset_index(name='calls_count')
#se crea la variable se llama a group by para hacer subcategorias y de paso que me las cuente el size()/contador especifico
#y el reset reset_index(name='calls_count') da la escenciao columan a los datos obtenidos da cuenta de que son

print(calls_per_user_month.head())
# Out:
#    user_id  month  calls_count
# 0     1000     12           16
# 1     1001      8           27
# 2     1001      9           49
# 3     1001     10           65
# 4     1001     11           64

# %%
# Calcula la cantidad de minutos usados por cada usuario al mes. Guarda el resultado.


cantidad_minutos_xusuario = calls.groupby(['user_id','month'])['duration'].sum().reset_index().sort_values(['user_id'])
# se saca la informacion prefiltrata y sumada por la duracion en minutos, usa el reset index para asignarlo como dataframe y editarlo
#luego se ordena
print(cantidad_minutos_xusuario.head())
# Out:
#    user_id  month  duration
# 0     1000     12    116.83
# 1     1001      8    171.14
# 2     1001      9    297.69
# 3     1001     10    374.11
# 4     1001     11    404.59

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Problema con la facturación recurrente (minutos): estás sumando las duraciones de llamadas en bruto, pero los minutos facturados deben basarse en las duraciones por llamada redondeadas hacia arriba al siguiente minuto antes de la agregación mensual. Por favor, aplica primero el redondeo y luego vuelve a agregar los minutos mensuales.
#
# </div>

# %%
calls['duration'] = np.ceil(calls['duration'])

# %%
# Calcula el número de mensajes enviados por cada usuario al mes. Guarda el resultado.
#messages
m_enviados_xusariomes = messages.groupby(['user_id','month']).size().reset_index(name='mensajes_x_usuario')
print(m_enviados_xusariomes)
# Out:
#       user_id  month  mensajes_x_usuario
# 0        1000     12                  11
# 1        1001      8                  30
# 2        1001      9                  44
# 3        1001     10                  53
# 4        1001     11                  36
# ...       ...    ...                 ...
# 1801     1496      9                  21
# 1802     1496     10                  18
# 1803     1496     11                  13
# 1804     1496     12                  11
# 1805     1497     12                  50
#
# [1806 rows x 3 columns]

# %%
# Calcula el volumen del tráfico de Internet usado por cada usuario al mes. Guarda el resultado.
trafico_internet_xusuariomes = internet.groupby(['user_id','month'])['mb_used'].sum().reset_index()
print(trafico_internet_xusuariomes)
# Out:
#       user_id  month   mb_used
# 0        1000     12   1901.47
# 1        1001      8   6919.15
# 2        1001      9  13314.82
# 3        1001     10  22330.49
# 4        1001     11  18504.30
# ...       ...    ...       ...
# 2272     1498     12  23137.69
# 2273     1499      9  12984.76
# 2274     1499     10  19492.43
# 2275     1499     11  16813.83
# 2276     1499     12  22059.21
#
# [2277 rows x 3 columns]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Problema de facturación recurrente (internet): el uso mensual debe redondearse hacia arriba a GB completos (1 GB = 1024 MB) antes de calcular el exceso. Sumar los MB sin aplicar el redondeo mensual al alza a GB distorsionará los ingresos.
#
# </div>

# %%
# Después de agregar por usuario y mes:
trafico_internet_xusuariomes = internet.groupby(['user_id','month'])['mb_used'].sum().reset_index()

# APLICAR el redondeo hacia arriba a GB completos:
trafico_internet_xusuariomes['gb_used'] = np.ceil(trafico_internet_xusuariomes['mb_used'] / 1024)

# %% [markdown]
# [Junta los datos agregados en un DataFrame para que haya un registro que represente lo que consumió un usuario único en un mes determinado.]

# %%
# Fusiona los datos agregados (no los originales)
# Primera unión: calls + minutos
consumom_callsmin = calls_per_user_month.merge(cantidad_minutos_xusuario, on=['user_id','month'], how='left')

# Segunda unión: calls + minutos + mensajes
consumom_callsminmensj = consumom_callsmin.merge(m_enviados_xusariomes, on=['user_id','month'], how='left') 

# Tercera unión: calls + minutos + mensajes + internet
consumom_total = consumom_callsminmensj.merge(trafico_internet_xusuariomes, on=['user_id','month'], how='left')

print(f"Filas en el resultado final: {len(consumom_total)}")
print(consumom_total.head())
# Out:
# Filas en el resultado final: 2258
#    user_id  month  calls_count  duration  mensajes_x_usuario   mb_used  \
# 0     1000     12           16    116.83                11.0   1901.47
# 1     1001      8           27    171.14                30.0   6919.15
# 2     1001      9           49    297.69                44.0  13314.82
# 3     1001     10           65    374.11                53.0  22330.49
# 4     1001     11           64    404.59                36.0  18504.30
#
#    gb_used
# 0      2.0
# 1      7.0
# 2     14.0
# 3     22.0
# 4     19.0

# %% [markdown]
# [Calcula los ingresos mensuales por usuario (resta el límite del paquete gratuito del número total de llamadas, mensajes de texto y datos; multiplica el resultado por el valor del plan de llamadas; añade la tarifa mensual en función del plan de llamadas). Nota: Dadas las condiciones del plan, ¡esto podría no ser tan trivial como un par de líneas! Así que no pasa nada si dedicas algo de tiempo a ello.]

# %%
# Unir consumo con información de planes + correccion de nombre columna
users = users.rename(columns={'plan': 'plan_name'})
# print(users.head())
mascolumnas = consumom_total.merge(users, on='user_id', how='left')
#print(mascolumnas)
columnas_totales = mascolumnas.merge(plans, on='plan_name',how='left')
print(columnas_totales)
# Out:
#       user_id  month_x  calls_count  duration  mensajes_x_usuario   mb_used  \
# 0        1000       12           16    116.83                11.0   1901.47
# 1        1001        8           27    171.14                30.0   6919.15
# 2        1001        9           49    297.69                44.0  13314.82
# 3        1001       10           65    374.11                53.0  22330.49
# 4        1001       11           64    404.59                36.0  18504.30
# ...       ...      ...          ...       ...                 ...       ...
# 2253     1498       12           39    324.77                 NaN  23137.69
# 2254     1499        9           41    330.37                 NaN  12984.76
# 2255     1499       10           53    363.28                 NaN  19492.43
# 2256     1499       11           45    288.56                 NaN  16813.83
# 2257     1499       12           65    468.10                 NaN  22059.21
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Después de hacer el merge, tienes tanto `month_x` como `month_y`, lo que hace que el “mes de facturación” sea ambiguo. Considera conservar una sola columna de mes que represente el mes de uso (de las tablas de uso agregadas) y eliminar/evitar las columnas del mes de registro de `users` antes del merge. Además, trata los campos de uso mensual faltantes (p. ej., `mensajes_x_usuario`) como 0 antes de los cálculos para que los ingresos se basen en un uso mensual completo.
#
# </div>

# %%
columnas_totales
# Out:
#       user_id  month_x  calls_count  duration  mensajes_x_usuario   mb_used  \
# 0        1000       12           16    116.83                11.0   1901.47
# 1        1001        8           27    171.14                30.0   6919.15
# 2        1001        9           49    297.69                44.0  13314.82
# 3        1001       10           65    374.11                53.0  22330.49
# 4        1001       11           64    404.59                36.0  18504.30
# ...       ...      ...          ...       ...                 ...       ...
# 2253     1498       12           39    324.77                 NaN  23137.69
# 2254     1499        9           41    330.37                 NaN  12984.76
# 2255     1499       10           53    363.28                 NaN  19492.43
# 2256     1499       11           45    288.56                 NaN  16813.83
# 2257     1499       12           65    468.10                 NaN  22059.21
#
# ...

# %%
# 1. Limpiar users antes del merge
users_clean = users[['user_id', 'plan_name', 'age', 'city']].copy()

# 2. Hacer merges sin conflictos
mascolumnas = consumom_total.merge(users_clean, on='user_id', how='left')
columnas_totales = mascolumnas.merge(plans, on='plan_name', how='left')

# 3. Tratar valores faltantes como 0
# Tratar todos los valores faltantes de uso como 0
columnas_totales['mensajes_x_usuario'] = columnas_totales['mensajes_x_usuario'].fillna(0)
columnas_totales['mb_used'] = columnas_totales['mb_used'].fillna(0)
columnas_totales['duration'] = columnas_totales['duration'].fillna(0)

# %%
plans
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_fee  usd_per_mb  usd_per_message  usd_per_minute plan_name
# 0               20    0.009766             0.03            0.03      surf
# 1               70    0.006836             0.01            0.01  ultimate

# %%
# PASO 1: Preparar la tabla plans con las columnas necesarias
# Crear la columna gb_per_month_included a partir de mb_per_month_included
plans['gb_per_month_included'] = plans['mb_per_month_included'] / 1024

# Restaurar usd_per_gb (revertir el cambio anterior que causó problemas)
plans['usd_per_gb'] = plans['usd_per_mb'] * 1024
plans = plans.drop('usd_per_mb', axis=1)  # Eliminar la columna problemática

print("Tabla plans corregida:")
print(plans)
# PASO 2: Aplicar las correcciones del revisor
# CORRECCIÓN 1: Redondear cada llamada individual ANTES de agregar
calls['duration_rounded'] = np.ceil(calls['duration'])

# Ahora agregar usando la duración redondeada
cantidad_minutos_xusuario = calls.groupby(['user_id','month'])['duration_rounded'].sum().reset_index()

# CORRECCIÓN 2: Para internet - agregar primero, luego convertir a GB y redondear
trafico_internet_xusuariomes = internet.groupby(['user_id','month'])['mb_used'].sum().reset_index()

# Convertir a GB y redondear hacia arriba DESPUÉS de la agregación
trafico_internet_xusuariomes['gb_used'] = np.ceil(trafico_internet_xusuariomes['mb_used'] / 1024)

# CORRECCIÓN 3: Limpiar users antes del merge para evitar month_x y month_y
users_clean = users[['user_id', 'plan_name']].copy()  # Solo las columnas necesarias

print("Datos preparados correctamente")
# PASO 3: Hacer los merges paso a paso
consumo_total = calls_per_user_month.merge(cantidad_minutos_xusuario, on=['user_id','month'], how='outer')
consumo_total = consumo_total.merge(m_enviados_xusariomes, on=['user_id','month'], how='outer')
consumo_total = consumo_total.merge(trafico_internet_xusuariomes, on=['user_id','month'], how='outer')

# Tratar valores faltantes como 0
consumo_total = consumo_total.fillna(0)

# Ahora hacer merge con users y plans
consumo_total = consumo_total.merge(users_clean, on='user_id', how='left')
consumo_total = consumo_total.merge(plans, on='plan_name', how='left')

print(f"Tabla final tiene {len(consumo_total)} filas")
print("Columnas disponibles:", consumo_total.columns.tolist())
consumo_total['exceso_minutos'] = (consumo_total['duration_rounded'] - consumo_total['minutes_included']).clip(lower=0)
consumo_total['exceso_mensajes'] = (consumo_total['mensajes_x_usuario'] - consumo_total['messages_included']).clip(lower=0)
consumo_total['exceso_gb'] = (consumo_total['gb_used'] - consumo_total['gb_per_month_included']).clip(lower=0)
# Out:
# Tabla plans corregida:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_fee  usd_per_message  usd_per_minute plan_name  \
# 0               20             0.03            0.03      surf
# 1               70             0.01            0.01  ultimate
#
#    gb_per_month_included  usd_per_gb
# 0                   15.0        10.0
# 1                   30.0         7.0
# Datos preparados correctamente
# Tabla final tiene 2293 filas
# Columnas disponibles: ['user_id', 'month', 'calls_count', 'duration_rounded', 'mensajes_x_usuario', 'mb_used', 'gb_used', 'plan_name', 'messages_included', 'mb_per_month_included', 'minutes_included', 'usd_monthly_fee', 'usd_per_message', 'usd_per_minute', 'gb_per_month_included', 'usd_per_gb']

# %%
# PASO 4: Calcular ingresos finales (esto es lo que falta)
consumo_total['ingreso_mensual'] = (
    consumo_total['usd_monthly_fee'] + 
    consumo_total['exceso_minutos'] * consumo_total['usd_per_minute'] +
    consumo_total['exceso_mensajes'] * consumo_total['usd_per_message'] +
    consumo_total['exceso_gb'] * consumo_total['usd_per_gb']
)

print("Cálculo de ingresos completado")
print(f"Ingreso promedio mensual: ${consumo_total['ingreso_mensual'].mean():.2f}")
# Out:
# Cálculo de ingresos completado
# Ingreso promedio mensual: $64.35

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La lógica de cálculo de ingresos está cerca, pero aún no sigue las reglas de facturación del proyecto porque los minutos y el uso de datos no se redondean como se requiere (minutos por llamada redondeados hacia arriba; datos mensuales redondeados hacia arriba a GB completos). Considera corregir primero esos cálculos de uso upstream y, después, volver a calcular los excesos (overages) y los ingresos para que los resultados finales de ingresos sean válidos.
#
# </div>

# %%
consumo_total
# Out:
#       user_id  month  calls_count  duration_rounded  mensajes_x_usuario  \
# 0        1000     12         16.0             124.0                11.0
# 1        1001      8         27.0             182.0                30.0
# 2        1001      9         49.0             315.0                44.0
# 3        1001     10         65.0             393.0                53.0
# 4        1001     11         64.0             426.0                36.0
# ...       ...    ...          ...               ...                 ...
# 2288     1349     12          0.0               0.0                61.0
# 2289     1361      5          0.0               0.0                 2.0
# 2290     1482     10          0.0               0.0                 2.0
# 2291     1108     12          0.0               0.0                 0.0
# 2292     1311      6          0.0               0.0                 0.0
#
#        mb_used  gb_used plan_name  messages_included  mb_per_month_included  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor   v2       </b> <a class="tocSkip"></a>
#
#
# Excelente, lograste el cálculo correcto de ingreso mensual para los usuarios.
#
#
# </div>

# %% [markdown]
# ## Estudia el comportamiento de usuario

# %% [markdown]
# [Calcula algunas estadísticas descriptivas para los datos agregados y fusionados que nos sean útiles y que muestren un panorama general captado por los datos. Dibuja gráficos útiles para facilitar la comprensión. Dado que la tarea principal es comparar las tarifas y decidir cuál es más rentable, las estadísticas y gráficas deben calcularse por tarifa.]
#
# [En los comentarios hallarás pistas relevantes para las llamadas, pero no las hay para los mensajes e Internet. Sin embargo, el principio del estudio estadístico que se aplica para ellos es el mismo que para las llamadas.]

# %% [markdown]
# ### Llamadas

# %%
# Compara la duración promedio de llamadas por cada plan y por cada mes. Traza un gráfico de barras para visualizarla.
columnas_totales.describe()
# duracion promedio de llamadas por plan
duracion_por_plan_mes = columnas_totales.groupby(['plan_name', 'month'])['duration'].mean().reset_index()
print(duracion_por_plan_mes)
print('=*100')
# Crear el gráfico de barras
plt.figure(figsize=(20, 15))
#############################################################################################################
# parametros basicos
duracion_por_plan_mes.pivot(index='month', columns='plan_name', values='duration').plot(kind='bar')
plt.title('Duración promedio de llamadas por plan y mes')
plt.xlabel('Mes')
plt.ylabel('Duración promedio (minutos)')
plt.legend(title='Plan')
plt.show()
# Out:
#    plan_name  month    duration
# 0       surf      1  192.840000
# 1       surf      2  280.851111
# 2       surf      3  310.970000
# 3       surf      4  332.380000
# 4       surf      5  387.108000
# 5       surf      6  411.450625
# 6       surf      7  428.060917
# 7       surf      8  394.474717
# 8       surf      9  397.133298
# 9       surf     10  414.435733
# 10      surf     11  408.255415
# 11      surf     12  457.547074
# 12  ultimate      1  183.162500
# 13  ultimate      2  443.171667
# 14  ultimate      3  285.701667
# 15  ultimate      4  316.508095
# 16  ultimate      5  383.664828
# 17  ultimate      6  365.358222
# 18  ultimate      7  403.767288
# 19  ultimate      8  397.274789
# 20  ultimate      9  413.287326
# 21  ultimate     10  429.217238
# 22  ultimate     11  423.814683
# 23  ultimate     12  438.824832
# =*100

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tu gráfica se basa en promedios por plan y por mes, lo que colapsa la variabilidad a nivel de usuario. Para esta tarea, considera usar los totales por usuario y por mes (minutos mensuales por usuario) y luego comparar los planes graficando la media (opcionalmente con barras de error) entre usuarios en cada mes.
#
# </div>

# %%
# Compara el número de minutos mensuales que necesitan los usuarios de cada plan. Traza un histograma.
# Opción 1: Histograma separado por plan
plt.figure(figsize=(12, 6))

for plan in duracion_por_plan_mes['plan_name'].unique():
    data = duracion_por_plan_mes[duracion_por_plan_mes['plan_name'] == plan]['duration']
    plt.hist(data, alpha=0.7, label=plan, bins=20)

plt.title('Distribución de minutos mensuales por plan')
plt.xlabel('Minutos')
plt.ylabel('Frecuencia')
plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Mismo problema que arriba: el histograma se construye solo a partir de los 12 promedios por plan-mes, en lugar de a partir de la distribución de los minutos mensuales de los usuarios. Considera graficar histogramas usando totales por usuario-por-mes, separados por plan, para reflejar la distribución real de uso.
#
# </div>

# %% [markdown]
# Aqui se puede apreciar como hay una oportunidad de reducir el numero de minutos al plan a 400 ya que aproximadamente la gente suele usar mas de 400 minutos mensuales, para promocionar el plan mas caro

# %% [markdown]
# [Calcula la media y la variable de la duración de las llamadas para averiguar si los usuarios de los distintos planes se comportan de forma diferente al realizar sus llamadas.]

# %%
# SOLUCIÓN CORRECTA: Calcular estadísticas sobre totales mensuales de usuarios individuales

# Paso 1: Obtener totales mensuales por usuario individual (usando datos ya corregidos)
minutos_por_usuario_mes = consumo_total.groupby(['user_id', 'month', 'plan_name'])['duration_rounded'].sum().reset_index()

# Paso 2: Calcular estadísticas por plan sobre estos totales individuales
print("=== ESTADÍSTICAS DE MINUTOS MENSUALES POR PLAN ===")
for plan in minutos_por_usuario_mes['plan_name'].unique():
    datos_plan = minutos_por_usuario_mes[minutos_por_usuario_mes['plan_name'] == plan]['duration_rounded']
    
    print(f"\n--- Plan {plan.upper()} ---")
    print(f"Media: {datos_plan.mean():.2f} minutos")
    print(f"Varianza: {datos_plan.var():.2f}")
    print(f"Desviación estándar: {datos_plan.std():.2f}")
    print(f"Número de observaciones: {len(datos_plan)}")
# Out:
# === ESTADÍSTICAS DE MINUTOS MENSUALES POR PLAN ===
#
# --- Plan ULTIMATE ---
# Media: 430.45 minutos
# Varianza: 57844.46
# Desviación estándar: 240.51
# Número de observaciones: 720
#
# --- Plan SURF ---
# Media: 428.75 minutos
# Varianza: 54968.28
# Desviación estándar: 234.45
# Número de observaciones: 1573

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Estas estadísticas se calculan sobre los promedios mensuales, no sobre los totales mensuales de los usuarios. La tarea solicita la media y la varianza de las duraciones mensuales de llamadas de los usuarios por plan, así que considera calcular la media y la varianza (explícitamente) sobre los minutos por usuario por mes para cada plan.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor    v2      </b> <a class="tocSkip"></a>
#
# Bien hecho, el cálculo de indicadores está correcto
#
#
#
# </div>

# %%
# Traza un diagrama de caja para visualizar la distribución de la duración mensual de llamadas

# SOLUCIÓN CORRECTA: Usar datos con redondeo de facturación aplicado
plt.figure(figsize=(10, 6))

# Preparar los datos por plan usando la tabla CORREGIDA
surf_data = consumo_total[consumo_total['plan_name'] == 'surf']['duration_rounded']
ultimate_data = consumo_total[consumo_total['plan_name'] == 'ultimate']['duration_rounded']

# Crear el boxplot
plt.boxplot([surf_data, ultimate_data], labels=['Surf', 'Ultimate'])
plt.title('Distribución de duración mensual de llamadas por plan (con redondeo de facturación)')
plt.ylabel('Duración (minutos)')
plt.xlabel('Plan')
plt.grid(True, alpha=0.3)
plt.show()

# Mostrar estadísticas para confirmar
print("=== ESTADÍSTICAS DEL BOXPLOT ===")
print(f"Surf - Mediana: {surf_data.median():.2f}, Media: {surf_data.mean():.2f}")
print(f"Ultimate - Mediana: {ultimate_data.median():.2f}, Media: {ultimate_data.mean():.2f}")
# Out:
# === ESTADÍSTICAS DEL BOXPLOT ===
# Surf - Mediana: 425.00, Media: 428.75
# Ultimate - Mediana: 424.00, Media: 430.45

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Este boxplot está usando los valores de `duration` de tu tabla combinada usuario-mes, pero los pasos anteriores indican que los minutos no se calcularon con el redondeo requerido por llamada. Después de reconstruir los minutos correctos por usuario y por mes (con la regla de facturación aplicada), usa ese campo corregido de minutos mensuales para el boxplot, de modo que la distribución coincida con la tarea.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor    v2      </b> <a class="tocSkip"></a>
#
# Muy bien con el gráfico de boxplot
#
#
#
# </div>

# %% [markdown]
# [Elabora las conclusiones sobre el comportamiento de los usuarios con respecto a las llamadas. ¿Su comportamiento varía en función del plan?]

# %% [markdown]
# La distribucion de los datos en ambos planos se comporta similar, lo que mas varia son las colas ya que hay mas tendencia de Surf en la cola de llamadas por mes

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta conclusión está colocada en una celda de código, por lo que no se mostrará como se pretende. Considera moverla a una celda de Markdown y hacer referencia explícita a la evidencia de tus gráficos/estadísticas corregidos (medianas/dispersión/outliers) para responder si el comportamiento de llamadas difiere según el plan.
#
# </div>

# %% [markdown]
# ### Mensajes

# %%
columnas_totales
# Out:
#       user_id  month  calls_count  duration  mensajes_x_usuario   mb_used  \
# 0        1000     12           16    116.83                11.0   1901.47
# 1        1001      8           27    171.14                30.0   6919.15
# 2        1001      9           49    297.69                44.0  13314.82
# 3        1001     10           65    374.11                53.0  22330.49
# 4        1001     11           64    404.59                36.0  18504.30
# ...       ...    ...          ...       ...                 ...       ...
# 2253     1498     12           39    324.77                 0.0  23137.69
# 2254     1499      9           41    330.37                 0.0  12984.76
# 2255     1499     10           53    363.28                 0.0  19492.43
# 2256     1499     11           45    288.56                 0.0  16813.83
# 2257     1499     12           65    468.10                 0.0  22059.21
#
#       gb_used plan_name  age                                       city  \
# ...

# %%
# Comprara el número de mensajes que tienden a enviar cada mes los usuarios de cada plan

surf_dmesaj = columnas_totales[columnas_totales['plan_name'] == 'surf'][['user_id','plan_name','month','mensajes_x_usuario']]
ultimate_dmesaj = columnas_totales[columnas_totales['plan_name'] == 'ultimate'][['user_id','plan_name','month','mensajes_x_usuario']]

# Rellenar valores NaN y ordenar el DataFrame completo
surf_dmesaj['mensajes_x_usuario'] = surf_dmesaj['mensajes_x_usuario'].fillna(0)
ultimate_dmesaj['mensajes_x_usuario'] = ultimate_dmesaj['mensajes_x_usuario'].fillna(0)

# Ordenar por usuario y mes (en el DataFrame, no en la Serie)
surf_dmesaj = surf_dmesaj.sort_values(['user_id','month'])
ultimate_dmesaj = ultimate_dmesaj.sort_values(['user_id','month'])

print(surf_dmesaj)
print('='*100)
print(ultimate_dmesaj)

# quiero mostrarlo en grafica 

plt.figure(figsize=(12, 6))
plt.hist(surf_dmesaj['mensajes_x_usuario'], alpha=0.7, label='Surf', bins=30)
plt.hist(ultimate_dmesaj['mensajes_x_usuario'], alpha=0.7, label='Ultimate', bins=30)
plt.title('Distribución de mensajes por plan')
plt.xlabel('Número de mensajes')
plt.ylabel('Frecuencia')
plt.legend()
plt.show()
# Out:
#       user_id plan_name  month  mensajes_x_usuario
# 1        1001      surf      8                30.0
# 2        1001      surf      9                44.0
# 3        1001      surf     10                53.0
# 4        1001      surf     11                36.0
# 5        1001      surf     12                44.0
# ...       ...       ...    ...                 ...
# 2253     1498      surf     12                 0.0
# 2254     1499      surf      9                 0.0
# 2255     1499      surf     10                 0.0
# 2256     1499      surf     11                 0.0
# 2257     1499      surf     12                 0.0
#
# [1545 rows x 4 columns]
# ...
#       user_id plan_name  month  mensajes_x_usuario
# 0        1000  ultimate     12                11.0
# 19       1006  ultimate     11                15.0
# 20       1006  ultimate     12               139.0
# 26       1008  ultimate     10                21.0
# 27       1008  ultimate     11                37.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Para mantener la narrativa clara, considera separar el análisis de “Messages” y “Internet” en sus secciones correspondientes. En la sección de Messages, incluye estadísticas descriptivas específicas de mensajes (media/varianza/desviación estándar por plan) y una visualización centrada únicamente en SMS.
#
# </div>

# %%
# Compara la cantidad de tráfico de Internet consumido por usuarios por plan
surf_dinternet = columnas_totales[columnas_totales['plan_name'] == 'surf'][['user_id','plan_name','month','mb_used']]
ultimate_dinternet = columnas_totales[columnas_totales['plan_name'] == 'ultimate'][['user_id','plan_name','month','mb_used']]

# Ordenar por usuario y mes (en el DataFrame, no en la Serie)
surf_dinternet = surf_dinternet.sort_values(['user_id','month'])
ultimate_dinternet = ultimate_dinternet.sort_values(['user_id','month'])

print(surf_dmesaj)
print('='*100)
print(ultimate_dmesaj)

# quiero mostrarlo en grafica 

plt.figure(figsize=(12, 6))
plt.hist(surf_dinternet['mb_used'], alpha=0.7, label='Surf', bins=100)
plt.hist(ultimate_dinternet['mb_used'], alpha=0.7, label='Ultimate', bins=50)
plt.title('Distribución de consumo de internet en mb mensual por plan')
plt.xlabel('Mb Usadas')
plt.ylabel('Frecuencia')
plt.legend()
plt.show()
# Out:
#       user_id plan_name  month  mensajes_x_usuario
# 1        1001      surf      8                30.0
# 2        1001      surf      9                44.0
# 3        1001      surf     10                53.0
# 4        1001      surf     11                36.0
# 5        1001      surf     12                44.0
# ...       ...       ...    ...                 ...
# 2253     1498      surf     12                 0.0
# 2254     1499      surf      9                 0.0
# 2255     1499      surf     10                 0.0
# 2256     1499      surf     11                 0.0
# 2257     1499      surf     12                 0.0
#
# [1545 rows x 4 columns]
# ...
#       user_id plan_name  month  mensajes_x_usuario
# 0        1000  ultimate     12                11.0
# 19       1006  ultimate     11                15.0
# 20       1006  ultimate     12               139.0
# 26       1008  ultimate     10                21.0
# 27       1008  ultimate     11                37.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Este código está haciendo un análisis de Internet, pero vuelve a imprimir los DataFrames de mensajes, lo que hace que la salida sea engañosa. Considera imprimir/inspeccionar aquí los DataFrames específicos de Internet (o mover esta celda debajo del encabezado de Internet) para que los resultados mostrados coincidan con el análisis.
#
# </div>

# %%
surf_dinternet.describe()
# Out:
#            user_id        month       mb_used
# count  1545.000000  1545.000000   1545.000000
# mean   1244.198058     9.171521  16505.727372
# std     139.601017     2.473113   7847.816242
# min    1001.000000     1.000000      0.000000
# 25%    1120.000000     8.000000  11986.520000
# 50%    1251.000000    10.000000  16832.090000
# 75%    1359.000000    11.000000  20970.260000
# max    1499.000000    12.000000  70931.590000

# %%
ultimate_dinternet.describe()
# Out:
#            user_id       month       mb_used
# count   713.000000  713.000000    713.000000
# mean   1253.628331    9.158485  17278.003731
# std     151.037175    2.545952   7759.655167
# min    1000.000000    1.000000    290.060000
# 25%    1126.000000    8.000000  12707.180000
# 50%    1246.000000   10.000000  16866.450000
# 75%    1401.000000   11.000000  21003.900000
# max    1497.000000   12.000000  46595.330000

# %% [markdown]
# Considero que el comportamiento en terminos de distribuciones normales es similar en terminos de consumo de internet, pero el plan surf al ser mas barato es mas rentable teniendo en cuenta que su limite es = 15360 -> considero que podrian empobrecer el plan el surf a 10gb equivalentes a 10,024 gb y el ultimate dejarlo en 25bg que son 25600 mb y aun si la gente de la cola superior seguiria consimiento mas datos, por lo que significa mayor cobro o incluso la creacion de un paquete mas premium, adicionalmente se puede hacer un pareto ABC con estos productos situando la nueva categoria en C, para obtener mas dinero

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta celda está bajo el prompt de conclusiones de Messages, pero el texto trata sobre el uso de internet y la estrategia de precios en su lugar. Considera añadir una conclusión breve específicamente sobre el comportamiento de SMS por plan (cómo difieren las distribuciones y qué implica eso para los planes).
#
# </div>

# %% [markdown]
# [Elabora las conclusiones sobre el comportamiento de los usuarios con respecto a los mensajes. ¿Su comportamiento varía en función del plan?]

# %% [markdown]
# ### Internet

# %% [markdown]
# Su comportamiento tiende a se el mismo, por eso toca hacer un cambio de estrategia de ventas y distribucion de paquetes

# %% [markdown]
# [Elabora las conclusiones sobre cómo los usuarios tienden a consumir el tráfico de Internet. ¿Su comportamiento varía en función del plan?]

# %% [markdown]
# ## Ingreso

# %% [markdown]
# [Del mismo modo que has estudiado el comportamiento de los usuarios, describe estadísticamente los ingresos de los planes.]

# %%
columnas_totales
# Out:
#       user_id  month  calls_count  duration  mensajes_x_usuario   mb_used  \
# 0        1000     12           16    116.83                11.0   1901.47
# 1        1001      8           27    171.14                30.0   6919.15
# 2        1001      9           49    297.69                44.0  13314.82
# 3        1001     10           65    374.11                53.0  22330.49
# 4        1001     11           64    404.59                36.0  18504.30
# ...       ...    ...          ...       ...                 ...       ...
# 2253     1498     12           39    324.77                 0.0  23137.69
# 2254     1499      9           41    330.37                 0.0  12984.76
# 2255     1499     10           53    363.28                 0.0  19492.43
# 2256     1499     11           45    288.56                 0.0  16813.83
# 2257     1499     12           65    468.10                 0.0  22059.21
#
#       gb_used plan_name  age                                       city  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# En la sección de Income, considera añadir un resumen estadístico centrado y al menos una visualización de `ingreso_mensual` por plan (p. ej., histograma y/o boxplot). Mostrar la tabla completa es útil para depurar, pero todavía no responde al requisito de “describir estadísticamente”.
#
# </div>

# %%
# Estadísticas de flujo de dinero
ingresos_por_plan = consumo_total.groupby('plan_name')['ingreso_mensual']
print(ingresos_por_plan.describe())
# Out:
#             count       mean        std   min   25%    50%    75%     max
# plan_name
# surf       1573.0  60.706408  55.388042  20.0  20.0  40.36  80.36  590.37
# ultimate    720.0  72.313889  11.395108  70.0  70.0  70.00  70.00  182.00

# %% [markdown]
# Surf     = el # de registros 1573 el plan surf es mucho mas rentable por el numero de clientes = 60.706408
# Ultimate = el # de registros 720 el plan surf es mucho mas rentable por el numero de clientes = 72.313889
#
# lo mejor que se puede realizar es una nueva estrategia para reasignar los recursos de cada plan para hacer mas atractivo el plan de Ultimate y de esa forma darle mas peso monetario a la empresa

# %% [markdown]
# [Elabora las conclusiones sobre cómo difiere el ingreso entre los planes.]

# %% [markdown]
# ## Prueba las hipótesis estadísticas

# %% [markdown]
# [Prueba la hipótesis de que son diferentes los ingresos promedio procedentes de los usuarios de los planes de llamada Ultimate y Surf.]

# %% [markdown]
# [Elabora las hipótesis nula y alternativa, escoge la prueba estadística, determina el valor alfa.]

# %%
columnas_totales.columns
# Out:
# Index(['user_id', 'month', 'calls_count', 'duration', 'mensajes_x_usuario',
#        'mb_used', 'gb_used', 'plan_name', 'age', 'city', 'messages_included',
#        'mb_per_month_included', 'minutes_included', 'usd_monthly_fee',
#        'usd_per_mb', 'usd_per_message', 'usd_per_minute'],
#       dtype='object')

# %%
# Prueba las hipótesis
# H0 = no existe diferencia entre los promedios de ingresos entre ambos planes ultimate y surf
# HA = son diferentes los ingresos promedio procedentes de los usuarios de los planes de llamada Ultimate y Surf.
# alfa = 0.05

ingresos_plan_surf = consumo_total[consumo_total['plan_name']=='surf']['ingreso_mensual']
ingresos_plan_surf = ingresos_plan_surf.fillna(0)
ingresos_plan_ultimate = consumo_total[consumo_total['plan_name']=='ultimate']['ingreso_mensual']
ingresos_plan_ultimate = ingresos_plan_ultimate.fillna(0)
# print(ingresos_plan_surf)
# print(ingresos_plan_ultimate)
alfa = 0.05

# independientes = el mismo suceso sobre dos poblaciones diferentes
t_stat, p_value = st.ttest_ind(ingresos_plan_ultimate, ingresos_plan_surf, equal_var=False) #Libreria stats st
print('Se recahza la hipotesis nula porque el valor es menor a 0.05 el resultado es:',p_value)
print('Los ingresos promedio son significativamente diferente')
print('La diferencia es bastante significativa porque no esta cerca de 0 (igualdad relativa)',t_stat)


# dependientes/relacionadas =  mas un suceso sobre una pobacion especifica
#t_stat, p_val = stats.ttest_rel(antes, despues)
# Out:
# Se recahza la hipotesis nula porque el valor es menor a 0.05 el resultado es: 3.1703905481135734e-15
# Los ingresos promedio son significativamente diferente
# La diferencia es bastante significativa porque no esta cerca de 0 (igualdad relativa) 7.952094891333888

# %% [markdown]
# [Prueba la hipótesis de que el ingreso promedio de los usuarios del área NY-NJ es diferente al de los usuarios de otras regiones.]

# %% [markdown]
# [Elabora las hipótesis nula y alternativa, escoge la prueba estadística, determina el valor alfa.]

# %%
consumo_total
# Out:
#       user_id  month  calls_count  duration_rounded  mensajes_x_usuario  \
# 0        1000     12         16.0             124.0                11.0
# 1        1001      8         27.0             182.0                30.0
# 2        1001      9         49.0             315.0                44.0
# 3        1001     10         65.0             393.0                53.0
# 4        1001     11         64.0             426.0                36.0
# ...       ...    ...          ...               ...                 ...
# 2288     1349     12          0.0               0.0                61.0
# 2289     1361      5          0.0               0.0                 2.0
# 2290     1482     10          0.0               0.0                 2.0
# 2291     1108     12          0.0               0.0                 0.0
# 2292     1311      6          0.0               0.0                 0.0
#
#        mb_used  gb_used plan_name  messages_included  mb_per_month_included  \
# ...

# %%
consumo_total = consumo_total.merge(users[['user_id','city']], on='user_id', how='left')

# %%
consumo_total.head()
# Out:
#    user_id  month  calls_count  duration_rounded  mensajes_x_usuario  \
# 0     1000     12         16.0             124.0                11.0
# 1     1001      8         27.0             182.0                30.0
# 2     1001      9         49.0             315.0                44.0
# 3     1001     10         65.0             393.0                53.0
# 4     1001     11         64.0             426.0                36.0
#
#     mb_used  gb_used plan_name  messages_included  mb_per_month_included  ...  \
# 0   1901.47      2.0  ultimate               1000                  30720  ...
# 1   6919.15      7.0      surf                 50                  15360  ...
# 2  13314.82     14.0      surf                 50                  15360  ...
# 3  22330.49     22.0      surf                 50                  15360  ...
# 4  18504.30     19.0      surf                 50                  15360  ...
#
#    usd_monthly_fee  usd_per_message  usd_per_minute  gb_per_month_included  \
# ...

# %%
# Prueba las hipótesis
# H0 = El ingreso promedio de NY-NJ es igual a los usuarios de otras regiones
# HA = El ingreso promedio de NY-NJ es diferente a los usuarios de otras regiones
# alfa = 0.05

ingreso_prom_NYNJ = consumo_total[consumo_total['city']=='New York-Newark-Jersey City, NY-NJ-PA MSA']['ingreso_mensual']
ingreso_prom_otrasR = consumo_total[consumo_total['city']!='New York-Newark-Jersey City, NY-NJ-PA MSA']['ingreso_mensual']
ingreso_prom_NYNJ = ingreso_prom_NYNJ.fillna(0) 
ingreso_prom_otrasR = ingreso_prom_otrasR.fillna(0) 
alfa = 0.05

# independientes = el mismo suceso sobre dos poblaciones diferentes
t_stat, p_value = st.ttest_ind(ingreso_prom_NYNJ,ingreso_prom_otrasR , equal_var=False) #Libreria stats st
print('Se rechaza la hipotesis nula porque la probabilidad de que los datos sean iguales es menor a mi margen de error del 0.05',p_value)
print('La diferencia es situl porque no esta cercana a 0 entre ambos datos',t_stat)
# Out:
# Se rechaza la hipotesis nula porque la probabilidad de que los datos sean iguales es menor a mi margen de error del 0.05 0.0335256158853001
# La diferencia es situl porque no esta cercana a 0 entre ambos datos -2.1309454999502133

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor     v2       </b> <a class="tocSkip"></a>
#
# Bien hecho con los tests, fueron realizados de forma correcta.
#
# Es importante mencionar que el t-test asume que las dos muestras tienen varianzas iguales Para verificar esa igualdad de varianzas podemos usar el **test de Levene**. Este nos dice si la variabilidad entre los grupos es *estadísticamente diferente*. En futuros notebooks podrías utilizar este test para decidir sobre la igualdad de varianzas. En corto, el flujo sería así
#
# 1. Usamos `levene()` para verificar si las varianzas son iguales.
# 2. Dependiendo del resultado, usamos `ttest_ind()` con el argumento `equal_var`:
#    - `equal_var=True` si Levene dice que las varianzas son iguales (p > 0.05).
#    - `equal_var=False` si Levene dice que las varianzas son diferentes (p < 0.05).
#
# </div>

# %% [markdown]
# ## Conclusión general
#
# [En esta sección final, enumera tus conclusiones importantes. Asegúrate de que estas abarquen todas las decisiones (suposiciones) importantes que adoptaste y que determinaron la forma elegida para procesar y analizar los datos.]

# %% [markdown]
# Con base en mi conclusion anterior 'Considero que el comportamiento en terminos de distribuciones normales es similar en terminos de consumo de internet, pero el plan surf al ser mas barato es mas rentable teniendo en cuenta que su limite es = 15360 -> considero que podrian empobrecer el plan el surf a 10gb equivalentes a 10,024 gb y el ultimate dejarlo en 25bg que son 25600 mb y aun si la gente de la cola superior seguiria consimiento mas datos, por lo que significa mayor cobro o incluso la creacion de un paquete mas premium, adicionalmente se puede hacer un pareto ABC con estos productos situando la nueva categoria en C, para obtener mas dinero'.
#
# Considero que lo mejor que podria realizar la empresa es un pareto teniendo en cuenta las distribuciiones de los planos en terminos de uso de recusos sin generar discriminacion de edad y de esa forma poder generar un ingreso superior de planes apetecidos por el publico teniendo subcategorias como por ejemplo el uso de megabites en internet, inclusive generando una separacion en 4 de los planes ofrecidos es fragmentando la distribucion de eleccion de planes teniendo en cuenta la tendencia de uso de datos, mensajes,llamdas de cada uno de los planes y asi poder tener producto tipo A / perosna basica sin interaccion con el telefono, perosna B/perosna que suele usar el celular a menudo, perosna C/ perosna que suele usar el celular mas de lo normal, perosna D/ perosna que tiende a pasar un% alto de su dia interactuando con el celular.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor    v2    </b> <a class="tocSkip"></a>
#
# Buen trabajo con las conclusiones. Para reforzarlas aún más, te sugiero incluir algunos valores clave de las métricas utilizadas. Esto le dará mayor solidez a tus afirmaciones y facilitará que quienes las lean comprendan mejor la base de tu análisis.
#
# </div>
